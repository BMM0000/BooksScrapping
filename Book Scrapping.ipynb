# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %%
with open('scrapbooks.html', 'r') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="no-js" lang="en-us">
# <head>
# <title>All products | Books to Scrape - Sandbox</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="NOARCHIVE,NOSNIPPET,NOFOLLOW,NOINDEX" name="robots"/>
# <link href="static/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="static/css/bootstrap-theme.min.css" rel="stylesheet"/>
# <link href="static/css/styles.css" rel="stylesheet"/>
# <link href="static/images/favicon.ico" rel="icon"/>
# </head>
# <body>
# <header>
# <div class="container-fluid">
# <div class="page_inner">
# <div class="row">
# <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a></div>
# <div class="col-sm-4">
# <form action="search.html" class="form-horizontal" method="get">
# <input name="csrfmiddlewaretoken" type="hidden" value="zRWZCTmnkDYP9o7s0mf0d0qlR2mi3uX9"/>
# <div class="input-group">
# ...

# %%
soup.h3.a.string
# Out:
# 'A Light in the ...'
